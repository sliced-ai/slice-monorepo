# %%
# !pip install -q accelerate transformers torch pynvml matplotlib

# %%
# !python inference.py
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Device: cuda:0, Inference 1:
# Temperature: 0.9252763394220196
# Top_p: 0.8301373155618434
# Max_new_tokens: 105
# Generated Text: Explain to me the difference between nuclear fission and fusion.
#
# Nuclear fission creates two small pieces of material: a very heavy element called uranium, and a much lighter element called a fission fragment. Fission is the process that happens in atoms like Uranium 235 when a neutron strikes the nucleus, causing a proton to split.
# ...
